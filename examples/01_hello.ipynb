# %% [markdown]
# <a href="https://colab.research.google.com/github/xavierforge/colab-rust/blob/main/examples/01_hello_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -qO- https://github.com/xavierforge/colab-rust/archive/main.tar.gz | tar xz --strip-components=1
# !bash setup.sh
# %load_ext colab_rust

# %%
# %%rust
# println!("Hello from Rust on Colab!");
# let sum: i32 = (1..=100).sum();
# println!("Sum 1..100 = {sum}");

# %%
# %%rust
# :dep rand = "0.8"
# use rand::Rng;
# rand::thread_rng().gen_range(1..=100)
